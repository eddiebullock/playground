# %% [markdown]
# # pandas load + inspect

# %%
import pandas as pd

chunk_size = 10000  # Adjust this value based on your system's capabilities
for chunk in pd.read_csv("/Users/eb2007/Library/CloudStorage/OneDrive-UniversityofCambridge/Documents/PhD/data/data_c4_raw.csv", chunksize=chunk_size):
    print(chunk.head())
    # Process each chunk here (e.g., perform operations, save to another file, etc.)
