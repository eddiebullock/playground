# %% [markdown]
# # 03 – Probing curves
#
# This notebook plots probe accuracy as a function of layer depth using outputs from `results/probes/`:
# - Load per-layer probe accuracies for each model and dataset.
# - Plot accuracy vs. transformer layer index.
# - Compare baseline vs fine-tuned models and identify peak diagnostic layers.
#
# Implement helper functions to read `probes_*.json` files and generate the figures.
