# %% [markdown]
# # 04 – RSA analysis
#
# This notebook visualises representational similarity analysis (RSA) results from `results/rsa/`:
# - Load model RDMs and human RDMs.
# - Plot RDM heatmaps for selected layers and models.
# - Plot RSA correlations vs. layer depth (baseline vs fine-tuned).
# - Summarise Fisher r-to-z comparisons across conditions.
#
# Add code cells to read RDM `.npy` files and RSA summary JSONs and generate the plots.
