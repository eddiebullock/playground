# %% [markdown]
# # 05 – Error analysis
#
# This notebook performs unified error analysis across behavioural performance, probing, and activation patching:
# - Load baseline and fine-tuned behavioural results from `results/baseline/` and `results/finetune/`.
# - Load probe summaries from `results/probes/` and patching results from `results/patching/`.
# - Construct a mental state difficulty table and examine where models and humans diverge.
# - Relate probe accuracy and patching success to behavioural error patterns.
#
# Fill in data loading and plotting code using helper functions from `scripts/error_analysis.py` as needed.
