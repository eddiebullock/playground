# %% [markdown]
# # 02 – Finetuning curves
#
# This notebook visualises fine-tuning dynamics using outputs from `results/finetune/`:
# - Training loss trajectories per epoch and per step.
# - Validation accuracy per epoch on Mindreading and EU-Emotions.
# - Comparisons across hyperparameter settings (LR, LoRA rank).
#
# Populate the code cells to read metrics from `hparam_sweep/` and `full_runs/` subdirectories.
