# %% [markdown]
# # 01 – Baseline results
#
# This notebook loads baseline evaluation JSON files from `results/baseline/` and:
# - Computes summary statistics (accuracy, Wilson CIs, binomial tests vs chance).
# - Compares model performance to human benchmarks.
# - Generates tables and plots for EU-Emotions, Mindreading, and RMET.
#
# Fill in the analysis code once baseline runs have been generated on CSD3.
